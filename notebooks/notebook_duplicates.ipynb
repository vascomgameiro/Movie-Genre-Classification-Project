# %% [markdown]
# # Configurate Session

# %%
# %load_ext autoreload

import os
import sys

project_root = "/Users/carolinapinto/desktop/NL/Mainproject/Natural-Language"
if project_root not in sys.path:
    sys.path.append(project_root)
os.chdir(project_root)

print("Current working directory:", os.getcwd())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Current working directory: /Users/carolinapinto/Desktop/NL/Mainproject/Natural-Language

# %% [markdown]
# # Load Data

# %%
# %autoreload 2
from src.dataset import read_data

path = "data/raw/train.txt"
columns = ["title", "from", "genre", "director", "description"]

df = read_data(path, columns)
df.head(3)
# Out:
#                        title      from    genre      director  \
# 0               Ela Cheppanu    Telugu  romance        Ramana
# 1  A Nightmare on Elm Street  American   horror  Samuel Bayer
# 2            American Gothic  American   horror    John Hough
#
#                                          description
# 0  Sekhar (Tarun) is a graduate from IIM and work...
# 1  Kris Fowles (Katie Cassidy) goes to the Spring...
# 2  Cynthia is traumatized by the death of her bab...

# %% [markdown]
# # EDA

# %% [markdown]
# ### First Impressions

# %%
# %autoreload 2
print(df.info())
print("*" * 20)
repeated_titles = df["title"].value_counts()[df["title"].value_counts() > 1].head(5)
print(repeated_titles)
print("*" * 20)
popular_directors = df["director"].value_counts().head(5)
print(popular_directors)
print("*" * 20)
print(df["from"].value_counts().head(5))
print("*" * 20)
print("Number of duplicates:", df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8041 entries, 0 to 8040
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        8041 non-null   object
#  1   from         8041 non-null   object
#  2   genre        8041 non-null   object
#  3   director     8041 non-null   object
#  4   description  8041 non-null   object
# dtypes: object(5)
# memory usage: 314.2+ KB
# None
# ********************
# title
# Dracula               4
# The Crimson Circle    3
# Hindle Wakes          3
# Romance               3
# I Love You            3
# Name: count, dtype: int64
# ********************
# director
# Unknown            178
# Hanna-Barbera       46
# Lesley Selander     32
# Maurice Elvey       28
# Joseph Kane         23
# Name: count, dtype: int64
# ********************
# from
# American     4050
# British      1415
# Bollywood     632
# Telugu        276
# Tamil         261
# Name: count, dtype: int64
# ********************
# Number of duplicates: 18

# %% [markdown]
# ### Drop Duplicates

# %%
df[df.duplicated(keep=False)].sort_values("title").head(20)
# Out:
#                      title      from    genre                     director  \
# 7102           At Gunpoint  American  western             Alfred L. Werker
# 4053           At Gunpoint  American  western             Alfred L. Werker
# 3121            Black Rock  American   horror                Katie Aselton
# 4714            Black Rock  American   horror                Katie Aselton
# 6456       Captain America  American   action                  Albert Pyun
# 6285       Captain America  American   action                  Albert Pyun
# 226                  Creep   British   horror            Christopher Smith
# 4126                 Creep   British   horror            Christopher Smith
# 6576     Drive-In Massacre  American   horror                   Stu Segall
# 4563     Drive-In Massacre  American   horror                   Stu Segall
# 3527    Flesh and the Spur  American  western               Edward L. Cahn
# 4573    Flesh and the Spur  American  western               Edward L. Cahn
# 6618          Leo the Last   British    drama                 John Boorman
# 5032          Leo the Last   British    drama                 John Boorman
# 7474  More Dead Than Alive  American  western                 Robert Sparr
# 7692  More Dead Than Alive  American  western                 Robert Sparr
# 555           Now or Never  American   comedy  Fred C. Newmeyer, Hal Roach
# 5773          Now or Never  American   comedy  Fred C. Newmeyer, Hal Roach
# 4803   Planet of Dinosaurs  American   sci-fi                   James Shea
# 3280   Planet of Dinosaurs  American   sci-fi                   James Shea
#
#                                             description
# 7102  Plainview is a peaceful town, all the better f...
# 4053  Plainview is a peaceful town, all the better f...
# 3121  Sarah (Kate Bosworth) invites her childhood fr...
# 4714  Sarah (Kate Bosworth) invites her childhood fr...
# 6456  In Fascist Italy in 1936, the government kidna...
# 6285  In Fascist Italy in 1936, the government kidna...
# 226   Arthur (Ken Campbell) and George (Vas Blackwoo...
# 4126  Arthur (Ken Campbell) and George (Vas Blackwoo...
# 6576  A couple go to a drive-in theater in a rural C...
# 4563  A couple go to a drive-in theater in a rural C...
# 3527  Tanner is a desperate prisoner who escapes fro...
# 4573  Tanner is a desperate prisoner who escapes fro...
# 6618  The ennui-afflicted heir to a deposed European...
# 5032  The ennui-afflicted heir to a deposed European...
# 7474  A murderer named Cain (Clint Walker) is releas...
# 7692  A murderer named Cain (Clint Walker) is releas...
# 555   A young woman, who is employed as a nanny to a...
# 5773  A young woman, who is employed as a nanny to a...
# 4803  After a mechanical failure aboard the spaceshi...
# 3280  After a mechanical failure aboard the spaceshi...

# %%
df.drop_duplicates(inplace=True)
# Reset index to ensure continuous indices
df = df.reset_index(drop=True)

# %% [markdown]
# ### Plots

# %%
# %autoreload 2

from src.plots import plot_movie_data

plot_movie_data(df)

# %%
# %autoreload 2

from src.plots import plot_stopword_frequency

plot_stopword_frequency(df, "description")

# %%
plot_stopword_frequency(df, "title")

# %%
# %autoreload 2
from src.plots import get_text_statistics
stats = get_text_statistics(df, 'description')

# %%
# %autoreload 2
from src.plots import plot_histograms
plot_histograms(stats)

# %%
# %autoreload 2
from src.plots import plot_boxplots
plot_boxplots(stats)

# %%
# %autoreload 2
from sklearn.preprocessing import StandardScaler
from src.plots import plot_correlation_matrix, apply_pca
# Standardize the data outside the PCA function
scaler = StandardScaler()
scaled_data = scaler.fit_transform(stats)

plot_correlation_matrix(stats)
pca_df, pca = apply_pca(scaled_data, df['genre'])

# %% [markdown]
# ### Standardize Directors

# %%
from collections import defaultdict
import re
from src.directors import create_name_map, map_director_names

#Create the mapping dictionary that maps the original director name to a standardized version
name_map = create_name_map(df)
#Map the names
map_director_names(df, name_map)

# %%
filtered_name_map = {key: value for key, value in name_map.items() if len(value) > 1}

# %%
filtered_name_map
# Out:
# {'kcbokadia': {'K C Bokadia', 'K. C. Bokadia'},
#  'hannabarbera': {'Hanna Barbera', 'Hanna-Barbera'},
#  'rajkumarkohli': {'Raj Kumar Kohli', 'Rajkumar Kohli'},
#  'rgspringsteen': {'R. G. Springsteen', 'R.G. Springsteen'},
#  '3directors': {'3 Directors', '3 directors'},
#  'chigurudutt': {'Chi Guru Dutt', 'Chi. Guru Dutt'},
#  'wsvandyke': {'W. S. Van Dyke', 'W.S. Van Dyke'},
#  'andredetoth': {'Andre DeToth', 'Andre de Toth'},
#  'tlvprasad': {'T. L. V. Prasad', 'T.L.V. Prasad'},
#  'yuenwooping': {'Yuen Woo Ping', 'Yuen Woo-ping'},
#  'kbalachander': {'K. Balachander', 'K.Balachander'},
#  'brchopra': {'B. R. Chopra', 'B.R. Chopra'},
#  'poonmankit': {'Poon Man Kit', 'Poon Man-kit'},
#  'pramodpappan': {'Pramod - Pappan', 'Pramod Pappan'},
#  'vvvinayak': {'V. V. Vinayak', 'V.V. Vinayak'},
#  'abhimsingh': {'A. Bhim Singh', 'A. Bhimsingh'},
#  'dwgriffith': {'D. W. Griffith', 'D.W. Griffith'},
#  'johnmackenzie': {'John MacKenzie', 'John Mackenzie'},
#  'vkprakash': {'V. K. Prakash', 'V.K.Prakash'},
#  'xuexiaolu': {'Xue Xiao Lu', 'Xue Xiaolu'},
#  'rajashekar': {'Raja Shekar', 'Rajashekar'},
#  'yvschowdary': {'Y. V. S. Chowdary', 'Y.V.S. Chowdary'},
#  'jscardone': {'J. S. Cardone', 'J.S. Cardone'},
#  'coenbrothers': {'Coen Brothers', 'Coen brothers'},
#  'cvrajendran': {'C. V. Rajendran', 'C.V. Rajendran'},
#  'farrellybrothers': {'Farrelly Brothers', 'Farrelly brothers'},
#  'vsamudra': {'V Samudra', 'V. Samudra'}}

# %%
df.head(5)
# Out:
#                        title       from    genre      director  \
# 0               Ela Cheppanu     Telugu  romance        ramana
# 1  A Nightmare on Elm Street   American   horror   samuelbayer
# 2            American Gothic   American   horror     johnhough
# 3                       Gang  Bollywood    crime    mazharkhan
# 4         Intimate Relations    British    drama  charlesfrank
#
#                                          description
# 0  Sekhar (Tarun) is a graduate from IIM and work...
# 1  Kris Fowles (Katie Cassidy) goes to the Spring...
# 2  Cynthia is traumatized by the death of her bab...
# 3  Four friends, Gangu (Jackie Shroff), Abdul (Na...
# 4  Crisis in a middle-class family when the son f...

# %% [markdown]
# ### Duplicate Candidates

# %%
# %autoreload 2

from src.dataset import filter_duplicate_descriptions

filtered_df=filter_duplicate_descriptions(df, "description", "title")
filtered_df
# Out:
#                                                   title         from  \
# 5741                                        Black Dalia    Malayalam
# 4028                                    Anthima Theerpu       Telugu
# 435                                              Bhayya       Telugu
# 7419                                        Malaikottai        Tamil
# 3026                                      The Protector    Hong Kong
# 7693                                     Protector, The     American
# 3036                                           36 Hours      British
# 2444                                      Terror Street     American
# 6766                                        Harry Tracy     American
# 1452                             Harry Tracy, Desperado     Canadian
# 819                                     Little Big Horn     American
# 1009                               The Fighting Seventh     American
# 4839                                War of the Wildcats     American
# 1043                                    In Old Oklahoma     American
# 6283                                  Fanny by Gaslight      British
# 2999                                        Man of Evil      British
# 2826                       Omen III: The Final Conflict      British
# 1056                                 The Final Conflict     American
# 5885              Slam Dunk: Howling Basketman Spirit!!     Japanese
# 7303           Slam Dunk: Shohoku's Greatest Challenge!     Japanese
# 5016                            Mister Bug Goes to Town     American
# 2399                               Mr. Bug Goes to Town     American
# 3285                                    Fanny Hawthorne      British
# 3306                                       Hindle Wakes      British
# 7489                                          Jaihind 2        Tamil
# 5074                                         Jai Hind 2       Telugu
# 6850                                          Abhimanyu      Kannada
# 5550                                                13B    Bollywood
# 6630                                      Yavarum Nalam        Tamil
# 2316                                             Nayaki       Telugu
# 2307                                             Nayagi        Tamil
# 7204                                          Puli Veta       Telugu
# 2464                                       Vettaikkaran        Tamil
# 7830                                          Veedevadu       Telugu
# 1368                                          Yaar Ivan        Tamil
# 5498                                  Sivaji - The Boss       Telugu
# 4954                                             Sivaji        Tamil
# 6194                                               Agni        Tamil
# 7589                                              Agnee  Bangladeshi
# 4337                          Mula sa Kung Ano ang Noon     Filipino
# 3492  Mula sa Kung Ano ang Noon *(2015 commercial re...     Filipino
# 4176                                     Toshokan Sensō     Japanese
# 3686               Library War: The Wings of Revolution     Japanese
# 6046                               Pokémon 3: The Movie     Japanese
# 4720                                    Pikachu & Pichu     Japanese
# 3055                        Matir Moina (The Clay Bird)      Bengali
# 5676                                        Matir Moyna      Bengali
# 95                                    Neevalle Neevalle       Telugu
# 1641                                      Unnale Unnale        Tamil
# 7612                                            Roudram       Telugu
# 1546                                          Rowthiram        Tamil
# 5394  Norte, the End of History *(2014 commercial re...     Filipino
# 7990  Norte, the End of History *(2014 commercial re...     Filipino
# 4624                        YuYu Hakusho: Bonds of Fire     Japanese
# 3334                      YuYu Hakusho: The Golden Seal     Japanese
#
#           genre                       director  \
# 5741     action                        baburaj
# 4028     action                     advbaburaj
# 435      action                boopathypandian
# 7419     action                boopathypandian
# 3026     action               jamesglickenhaus
# 7693     action               jamesglickenhaus
# 3036      crime                montgomerytully
# 2444      crime                montgomerytully
# 6766    western                 williamagraham
# 1452    western                  williamgraham
# 819     western           charlesmarquiswarren
# 1009    western           charlesmarquiswarren
# 4839    western                  albertsrogell
# 1043    western                  albertsrogell
# 6283      drama                 anthonyasquith
# 2999      drama                 anthonyasquith
# 2826     horror                    grahambaker
# 1056     horror                    grahambaker
# 5885  animation                        unknown
# 7303  animation                        unknown
# 5016  animation                        unknown
# 2399  animation                  davefleischer
# 3285      drama                   mauriceelvey
# 3306      drama                   mauriceelvey
# 7489     action                          arjun
# 5074     action                     arjunsarja
# 6850     action                     arjunsarja
# 5550     horror                   vikramkkumar
# 6630     horror                    vikramkumar
# 2316     horror                 goverdhanreddy
# 2307     horror                           govi
# 7204     action                      babusivan
# 2464     action                     bbabusivan
# 7830     action                  tatinenisatya
# 1368     action                  tatinenisatya
# 5498     action                       sshankar
# 4954     action                        shankar
# 6194    romance                  ajrharikesava
# 7589     action               iftakarchowdhury
# 4337      drama                        lavdiaz
# 3492      drama                        lavdiaz
# 4176     sci-fi                   shinsukesato
# 3686  animation                 takayukihamana
# 6046  animation  yuyama,kunihikokunihikoyuyama
# 4720  animation  yuyama,kunihikokunihikoyuyama
# 3055      drama                   tarequemasud
# 5676    romance                     tarakmasud
# 95      romance                          jeeva
# 1641    romance                          jeeva
# 7612     action                          gokul
# 1546     action                          gokul
# 5394      drama                        lavdiaz
# 7990      drama                        lavdiaz
# 4624  animation                masakatsuiijima
# 3334  animation                    noriyukiabe
#
#                                             description
# 5741  A student of Sacred Heart Medical College is f...
# 4028  A student of Sacred Heart Medical College is f...
# 435   Anbu (Vishal) is a happy-go-lucky engineering ...
# 7419  Anbu (Vishal) is a happy-go-lucky engineering ...
# 3026  As noted above, Jackie Chan re-edited The Prot...
# 7693  As noted above, Jackie Chan re-edited The Prot...
# 3036  Bill Rogers (Dan Duryea), an American jet pilo...
# 2444  Bill Rogers (Dan Duryea), an American jet pilo...
# 6766  By the end of the 19th century, Butch Cassidy,...
# 1452  By the end of the 19th century, Butch Cassidy,...
# 819   Captain Phillip Donlin (Lloyd Bridges) and his...
# 1009  Captain Phillip Donlin (Lloyd Bridges) and his...
# 4839  Eastern school teacher Catherine Allen becomes...
# 1043  Eastern school teacher Catherine Allen becomes...
# 6283  Fanny (Phyllis Calvert) finishes at boarding s...
# 2999  Fanny (Phyllis Calvert) finishes at boarding s...
# 2826  Following the grisly suicide of the U.S. Ambas...
# 1056  Following the grisly suicide of the U.S. Ambas...
# 5885  Hanamichi Sakuragi is a delinquent and the lea...
# 7303  Hanamichi Sakuragi is a delinquent and the lea...
# 5016  Hoppity the Grasshopper, after a period spent ...
# 2399  Hoppity the Grasshopper, after a period spent ...
# 3285  In the (fictitious) Lancashire mill town of Hi...
# 3306  In the (fictitious) Lancashire mill town of Hi...
# 7489  Jaihind is the journey of five people, linked ...
# 5074  Jaihind is the journey of five people, linked ...
# 6850  Jaihind is the journey of five people, linked ...
# 5550  Manohar moves into a new apartment, 13B, on th...
# 6630  Manohar moves into a new apartment, 13B, on th...
# 2316  Nayaki is a horror movie . Nayaki is about Gay...
# 2307  Nayaki is a horror movie . Nayaki is about Gay...
# 7204  Ravi (Vijay), a youth from Thoothukudi, aspire...
# 2464  Ravi (Vijay), a youth from Thoothukudi, aspire...
# 7830  Sachin Joshi is a Kabaddi Player who loved a g...
# 1368  Sachin Joshi is a Kabaddi Player who loved a g...
# 5498  Sivaji, an Indian software architect, returns ...
# 4954  Sivaji, an Indian software architect, returns ...
# 6194  Tanisha is a young daughter of a man working f...
# 7589  Tanisha is a young daughter of a man working f...
# 4337  The Philippines, 1972. Mysterious things are h...
# 3492  The Philippines, 1972. Mysterious things are h...
# 4176  The background of the plot is based on the Sta...
# 3686  The background of the plot is based on the Sta...
# 6046  The film comes accompanied by a short mini-mov...
# 4720  The film comes accompanied by a short mini-mov...
# 3055  The film is set against the backdrop of unrest...
# 5676  The film is set against the backdrop of unrest...
# 95    The film opens with two people – a man (Aravin...
# 1641  The film opens with two people – a man (Aravin...
# 7612  The film starts in the 1980s. A young Shiva (J...
# 1546  The film starts in the 1980s. A young Shiva (J...
# 5394  The lives of three people take a turn when one...
# 7990  The lives of three people take a turn when one...
# 4624  While vacationing, Koenma is kidnapped by a pa...
# 3334  While vacationing, Koenma is kidnapped by a pa...

# %%
num_rows = filtered_df.shape[0]
print(f"Number of rows with duplicate descriptions: {num_rows}")
# Out:
# Number of rows with duplicate descriptions: 55

# %%
# %autoreload 2
from src.dataset import find_similar_descriptions

similar_pairs = find_similar_descriptions(df, "description")

# %%
print(similar_pairs)
# Out:
# [(6, 5948, np.float64(1.0000000000000002), 1.0), (95, 1641, np.float64(1.0), 1.0), (435, 7419, np.float64(1.0000000000000004), 1.0), (578, 7355, np.float64(1.0000000000000002), 1.0), (819, 1009, np.float64(1.0000000000000002), 1.0), (923, 1591, np.float64(1.0), 1.0), (974, 5102, np.float64(1.0), 1.0), (1043, 4839, np.float64(0.9999999999999999), 1.0), (1056, 2826, np.float64(1.0000000000000002), 1.0), (1368, 7830, np.float64(0.9999999999999999), 1.0), (1452, 6766, np.float64(1.0000000000000002), 1.0), (1517, 1760, np.float64(1.0000000000000002), 1.0), (1517, 2215, np.float64(1.0000000000000002), 1.0), (1546, 7612, np.float64(1.0000000000000002), 1.0), (1760, 2215, np.float64(1.0000000000000002), 1.0), (1941, 4509, np.float64(1.0000000000000002), 1.0), (1967, 3454, np.float64(1.0000000000000002), 1.0), (2088, 3987, np.float64(1.0000000000000002), 1.0), (2307, 2316, np.float64(1.0), 1.0), (2399, 5016, np.float64(0.9999999999999998), 1.0), (2444, 3036, np.float64(1.0000000000000002), 1.0), (2464, 7204, np.float64(1.0000000000000002), 1.0), (2753, 6178, np.float64(0.9784948209229177), 0.9655172413793104), (2837, 7310, np.float64(1.0000000000000002), 1.0), (2999, 6283, np.float64(1.0), 1.0), (3022, 6461, np.float64(1.0000000000000002), 1.0), (3026, 7693, np.float64(1.0), 1.0), (3055, 5676, np.float64(1.0000000000000002), 1.0), (3285, 3306, np.float64(0.9999999999999999), 1.0), (3334, 4624, np.float64(1.0000000000000013), 1.0), (3492, 4337, np.float64(1.0000000000000002), 1.0), (3542, 6515, np.float64(0.9767058689994236), 0.9230769230769231), (3629, 4917, np.float64(1.0), 1.0), (3671, 6853, np.float64(0.9999999999999999), 1.0), (3686, 4176, np.float64(0.9999999999999998), 1.0), (4028, 5741, np.float64(1.0000000000000002), 1.0), (4101, 6979, np.float64(1.0), 1.0), (4124, 4328, np.float64(1.0000000000000002), 1.0), (4720, 6046, np.float64(1.0000000000000002), 1.0), (4954, 5498, np.float64(1.0), 1.0), (5074, 6850, np.float64(1.0000000000000004), 1.0), (5074, 7489, np.float64(1.0000000000000004), 1.0), (5394, 7990, np.float64(1.0000000000000002), 1.0), (5550, 6630, np.float64(1.0), 1.0), (5678, 7934, np.float64(1.0000000000000002), 1.0), (5865, 6319, np.float64(1.0000000000000002), 1.0), (5885, 7303, np.float64(1.0000000000000002), 1.0), (6194, 7589, np.float64(1.0), 1.0), (6850, 7489, np.float64(1.0000000000000004), 1.0)]

# %%
length_of_similar_pairs = len(similar_pairs)
print("Number of similar pairs:", length_of_similar_pairs)
# Out:
# Number of similar pairs: 49

# %%
print(df.loc[[1370, 1648]])
# Out:
#                   title      from      genre       director  \
# 1370  Rabbit of Seville  American  animation  charlesmjones
# 1648         Hare Brush  American  animation    frizfreleng
#
#                                             description
# 1370  The cartoon opens with people filing in to see...
# 1648  In the boardroom of the Elmer J. Fudd Corporat...

# %%
print(df.loc[[95, 1641], ["description"]])
# Out:
#                                             description
# 95    The film opens with two people – a man (Aravin...
# 1641  The film opens with two people – a man (Aravin...

# %%
# %autoreload 2
from src.dataset import print_differences

print_differences(df, similar_pairs, "title")
print("\n")
print_differences(df, similar_pairs, "director")
print("\n")
print_differences(df, similar_pairs, "genre")
print("\n")
print_differences(df, similar_pairs, "from")

# %%
from src.dataset import validate_and_filter_duplicates_fuzzy
validate_and_filter_duplicates_fuzzy(df, similar_pairs, ["director"], threshold=80)

# %%
# %autoreload 2

from src.dataset import filter_duplicate_descriptions

filter_duplicate_descriptions(df, "description", "title")
# Out:
#                                      title         from      genre  \
# 2399                  Mr. Bug Goes to Town     American  animation
# 5016               Mister Bug Goes to Town     American  animation
# 6850                             Abhimanyu      Kannada     action
# 7489                             Jaihind 2        Tamil     action
# 2307                                Nayagi        Tamil     horror
# 2316                                Nayaki       Telugu     horror
# 6194                                  Agni        Tamil    romance
# 7589                                 Agnee  Bangladeshi     action
# 3686  Library War: The Wings of Revolution     Japanese  animation
# 4176                        Toshokan Sensō     Japanese     sci-fi
# 3055           Matir Moina (The Clay Bird)      Bengali      drama
# 5676                           Matir Moyna      Bengali    romance
# 3334         YuYu Hakusho: The Golden Seal     Japanese  animation
# 4624           YuYu Hakusho: Bonds of Fire     Japanese  animation
#
#               director                                        description
# 2399     davefleischer  Hoppity the Grasshopper, after a period spent ...
# 5016           unknown  Hoppity the Grasshopper, after a period spent ...
# 6850        arjunsarja  Jaihind is the journey of five people, linked ...
# 7489             arjun  Jaihind is the journey of five people, linked ...
# 2307              govi  Nayaki is a horror movie . Nayaki is about Gay...
# 2316    goverdhanreddy  Nayaki is a horror movie . Nayaki is about Gay...
# 6194     ajrharikesava  Tanisha is a young daughter of a man working f...
# 7589  iftakarchowdhury  Tanisha is a young daughter of a man working f...
# 3686    takayukihamana  The background of the plot is based on the Sta...
# 4176      shinsukesato  The background of the plot is based on the Sta...
# 3055      tarequemasud  The film is set against the backdrop of unrest...
# 5676        tarakmasud  The film is set against the backdrop of unrest...
# 3334       noriyukiabe  While vacationing, Koenma is kidnapped by a pa...
# 4624   masakatsuiijima  While vacationing, Koenma is kidnapped by a pa...

# %%
num_rows = filter_df2.shape[0]
print(f"Number of rows with duplicate descriptions: {num_rows}")
# Out:
# Number of rows with duplicate descriptions: 14

# %% [markdown]
# ### Candidate Duplicates

# %%
import pandas as pd
import re
from rapidfuzz import fuzz, process  # Using rapidfuzz for fast fuzzy matching
import unicodedata


def preprocess_and_find_merge_candidates(df, director_column, threshold=85):
    """
    Preprocesses director names and finds candidates for merging based on fuzzy matching.

    Parameters:
    df (pd.DataFrame): The original DataFrame containing director names.
    director_column (str): The column name containing the director names.
    threshold (int): Similarity score threshold for fuzzy matching (default: 85).

    Returns:
    pd.DataFrame: A DataFrame with potential merge candidates based on the similarity score,
                  including the original director names.
    """

    # Step 1: Preprocess the names (lowercase, normalize, and strip extra spaces)
    def preprocess_name(name):
        # Normalize and remove accents
        name = unicodedata.normalize("NFKD", name).encode("ascii", "ignore").decode("utf-8")
        # Remove extra spaces and commas, convert to lowercase
        name = re.sub(r"\s+", " ", name.strip())  # Replace multiple spaces with single space
        name = re.sub(r"[^\w\s,]", "", name)  # Remove special characters, keep commas

        # Remove single or double initials (e.g., "M.", "R A", "S.")
        name = re.sub(r"\b(?:[A-Z](?:\.|\s)){1,2}\b", "", name)  # Matches 1 or 2 initials with/without period

        return name.lower()

    # Step 2: Preprocess and split multiple names in the column
    df_temp = df.copy()  # Create a copy of the DataFrame to avoid modifying the original
    df_temp["processed_name"] = df_temp[director_column].apply(preprocess_name)
    df_temp["split_names"] = df_temp["processed_name"].apply(lambda x: x.split(","))

    # Track the original names before exploding
    df_temp["original_name"] = df[director_column]

    # Explode the DataFrame so that each name is on a separate row
    df_exploded = df_temp.explode("split_names")
    df_exploded["split_names"] = df_exploded["split_names"].str.strip()  # Strip extra spaces

    # Step 3: Define a function to find candidates for merging using fuzzy matching
    def find_merge_candidates(df, threshold=85):
        """
        Finds names that are candidates for merging based on fuzzy matching.
        """
        names = df["split_names"].unique()
        merge_candidates = []

        for name in names:
            # Get a list of all potential matches that exceed the threshold
            matches = process.extract(name, names, scorer=fuzz.ratio, limit=None)
            for match_name, score, _ in matches:  # Here we unpack the third value but ignore it
                if name != match_name and score >= threshold:
                    original_name = df[df["split_names"] == name]["original_name"].values[0]
                    potential_merge_original = df[df["split_names"] == match_name]["original_name"].values[0]
                    merge_candidates.append((original_name, name, potential_merge_original, match_name, score))

        return pd.DataFrame(
            merge_candidates,
            columns=[
                "Original Name",
                "Processed Name",
                "Potential Merge Original",
                "Potential Merge Processed",
                "Similarity Score",
            ],
        )

    # Step 4: Get the merge candidates DataFrame
    merge_candidates_df = find_merge_candidates(df_exploded, threshold)

    # Step 5: Sort the results for better readability
    merge_candidates_df.sort_values(by="Similarity Score", ascending=False, inplace=True)

    return merge_candidates_df

# %%
merge_candidates = preprocess_and_find_merge_candidates(df, "director", threshold=95)

# %%
merge_candidates.loc[:, ["Original Name", "Potential Merge Original", "Similarity Score"]].iloc[::2]

# %%
df.loc[(df["director"] == "Mrighdeep Singh Lamba") | (df["director"] == "Mrigdeep Singh Lamba")]

# %%
from collections import defaultdict


def clean_director_name(name: str):
    name = name.lower().replace(" ", "").replace("-", "")
    return re.sub(r"\.", "", name)


def create_name_map(df: pd.DataFrame):
    name_map = defaultdict(set)

    for i, row in df.iterrows():
        director_list = [name.strip() for name in row["director"].split(",")]

        for director in director_list:
            cleaned_name = clean_director_name(director)
            name_map[cleaned_name].add(director)

    return name_map


director_name_map = create_name_map(df)
filtered_name_map = {key: value for key, value in director_name_map.items() if len(value) > 1}


print("Directors with more than 1 value:")
filtered_name_map

# %%
import numpy as np

df.loc[df["director"] == "3 directors" "Director"] = np.nan
df.loc[:, "director"] = df.loc[:, "director"].replace("Unknown", np.nan)

# %% [markdown]
# # Preprocessing (NEEDS WORK!)

# %%
# %autoreload 2
from src.dataset import lemmatize_tokens, extract_noun_phrases, word_tokenize
import string


def preprocess_sentence(sentence: str) -> str:
    """Preprocess the sentence by tokenizing, lemmatizing, and joining noun phrases."""
    cleaned_sentence = sentence.translate(str.maketrans("", "", string.punctuation)).lower()
    tokens = word_tokenize(cleaned_sentence)
    noun_phrases = extract_noun_phrases(sentence)
    noun_phrases_joined = ["".join(phrase.split()) for phrase in noun_phrases]
    lemmatized_tokens = lemmatize_tokens(tokens)
    combined_tokens = list(set(lemmatized_tokens + noun_phrases_joined))
    return " ".join(combined_tokens)


df["title"] = df["title"].apply(preprocess_sentence)
df["description"] = df["description"].apply(preprocess_sentence)

# %% [markdown]
# # Feature Engineering

# %%
df["region"] = df["from"].map(
    {
        "American": "Western",
        "British": "Western",
        "Canadian": "Western",
        "Australian": "Western",
        "Bollywood": "South Asian",
        "Telugu": "South Asian",
        "Tamil": "South Asian",
        "Malayalam": "South Asian",
        "Bengali": "South Asian",
        "Kannada": "South Asian",
        "Marathi": "South Asian",
        "Punjabi": "South Asian",
        "Assamese": "South Asian",
        "Chinese": "East Asian",
        "Japanese": "East Asian",
        "South_Korean": "East Asian",
        "Hong Kong": "East Asian",
        "Filipino": "Southeast Asian",
        "Bangladeshi": "South Asian",
        "Russian": "European",
        "Turkish": "Middle Eastern",
        "Egyptian": "Middle Eastern",
        "Malaysian": "Southeast Asian",
    }
)

# %%
# %autoreload 2

from src.dataset import filter_duplicate_descriptions

filter_duplicate_descriptions(df, "description", "title")
# Out:
#                                                   title         from  \
# 5748                                        Black Dalia    Malayalam
# 4030                                    Anthima Theerpu       Telugu
# 435                                              Bhayya       Telugu
# 7436                                        Malaikottai        Tamil
# 3028                                      The Protector    Hong Kong
# 7711                                     Protector, The     American
# 3038                                           36 Hours      British
# 2445                                      Terror Street     American
# 6780                                        Harry Tracy     American
# 1452                             Harry Tracy, Desperado     Canadian
# 819                                     Little Big Horn     American
# 1009                               The Fighting Seventh     American
# 4845                                War of the Wildcats     American
# 1043                                    In Old Oklahoma     American
# 6292                                  Fanny by Gaslight      British
# 3001                                        Man of Evil      British
# 2828                       Omen III: The Final Conflict      British
# 1056                                 The Final Conflict     American
# 5894              Slam Dunk: Howling Basketman Spirit!!     Japanese
# 7319           Slam Dunk: Shohoku's Greatest Challenge!     Japanese
# 5022                            Mister Bug Goes to Town     American
# 2400                               Mr. Bug Goes to Town     American
# 3287                                    Fanny Hawthorne      British
# 3308                                       Hindle Wakes      British
# 7506                                          Jaihind 2        Tamil
# 5080                                         Jai Hind 2       Telugu
# 6864                                          Abhimanyu      Kannada
# 5556                                                13B    Bollywood
# 6644                                      Yavarum Nalam        Tamil
# 2316                                             Nayaki       Telugu
# 2307                                             Nayagi        Tamil
# 7220                                          Puli Veta       Telugu
# 2465                                       Vettaikkaran        Tamil
# 7848                                          Veedevadu       Telugu
# 1368                                          Yaar Ivan        Tamil
# 5504                                  Sivaji - The Boss       Telugu
# 4960                                             Sivaji        Tamil
# 6203                                               Agni        Tamil
# 7606                                              Agnee  Bangladeshi
# 4340                          Mula sa Kung Ano ang Noon     Filipino
# 3494  Mula sa Kung Ano ang Noon *(2015 commercial re...     Filipino
# 4179                                     Toshokan Sensō     Japanese
# 3688               Library War: The Wings of Revolution     Japanese
# 6055                               Pokémon 3: The Movie     Japanese
# 4725                                    Pikachu & Pichu     Japanese
# 3057                        Matir Moina (The Clay Bird)      Bengali
# 5682                                        Matir Moyna      Bengali
# 95                                    Neevalle Neevalle       Telugu
# 1641                                      Unnale Unnale        Tamil
# 7629                                            Roudram       Telugu
# 1546                                          Rowthiram        Tamil
# 5400  Norte, the End of History *(2014 commercial re...     Filipino
# 8008  Norte, the End of History *(2014 commercial re...     Filipino
# 4628                        YuYu Hakusho: Bonds of Fire     Japanese
# 3336                      YuYu Hakusho: The Golden Seal     Japanese
#
#           genre                       director  \
# 5748     action                        baburaj
# 4030     action                     advbaburaj
# 435      action                boopathypandian
# 7436     action                boopathypandian
# 3028     action               jamesglickenhaus
# 7711     action               jamesglickenhaus
# 3038      crime                montgomerytully
# 2445      crime                montgomerytully
# 6780    western                 williamagraham
# 1452    western                  williamgraham
# 819     western           charlesmarquiswarren
# 1009    western           charlesmarquiswarren
# 4845    western                  albertsrogell
# 1043    western                  albertsrogell
# 6292      drama                 anthonyasquith
# 3001      drama                 anthonyasquith
# 2828     horror                    grahambaker
# 1056     horror                    grahambaker
# 5894  animation                        unknown
# 7319  animation                        unknown
# 5022  animation                        unknown
# 2400  animation                  davefleischer
# 3287      drama                   mauriceelvey
# 3308      drama                   mauriceelvey
# 7506     action                          arjun
# 5080     action                     arjunsarja
# 6864     action                     arjunsarja
# 5556     horror                   vikramkkumar
# 6644     horror                    vikramkumar
# 2316     horror                 goverdhanreddy
# 2307     horror                           govi
# 7220     action                      babusivan
# 2465     action                     bbabusivan
# 7848     action                  tatinenisatya
# 1368     action                  tatinenisatya
# 5504     action                       sshankar
# 4960     action                        shankar
# 6203    romance                  ajrharikesava
# 7606     action               iftakarchowdhury
# 4340      drama                        lavdiaz
# 3494      drama                        lavdiaz
# 4179     sci-fi                   shinsukesato
# 3688  animation                 takayukihamana
# 6055  animation  yuyama,kunihikokunihikoyuyama
# 4725  animation  yuyama,kunihikokunihikoyuyama
# 3057      drama                   tarequemasud
# 5682    romance                     tarakmasud
# 95      romance                          jeeva
# 1641    romance                          jeeva
# 7629     action                          gokul
# 1546     action                          gokul
# 5400      drama                        lavdiaz
# 8008      drama                        lavdiaz
# 4628  animation                masakatsuiijima
# 3336  animation                    noriyukiabe
#
#                                             description           region
# 5748  A student of Sacred Heart Medical College is f...      South Asian
# 4030  A student of Sacred Heart Medical College is f...      South Asian
# 435   Anbu (Vishal) is a happy-go-lucky engineering ...      South Asian
# 7436  Anbu (Vishal) is a happy-go-lucky engineering ...      South Asian
# 3028  As noted above, Jackie Chan re-edited The Prot...       East Asian
# 7711  As noted above, Jackie Chan re-edited The Prot...          Western
# 3038  Bill Rogers (Dan Duryea), an American jet pilo...          Western
# 2445  Bill Rogers (Dan Duryea), an American jet pilo...          Western
# 6780  By the end of the 19th century, Butch Cassidy,...          Western
# 1452  By the end of the 19th century, Butch Cassidy,...          Western
# 819   Captain Phillip Donlin (Lloyd Bridges) and his...          Western
# 1009  Captain Phillip Donlin (Lloyd Bridges) and his...          Western
# 4845  Eastern school teacher Catherine Allen becomes...          Western
# 1043  Eastern school teacher Catherine Allen becomes...          Western
# 6292  Fanny (Phyllis Calvert) finishes at boarding s...          Western
# 3001  Fanny (Phyllis Calvert) finishes at boarding s...          Western
# 2828  Following the grisly suicide of the U.S. Ambas...          Western
# 1056  Following the grisly suicide of the U.S. Ambas...          Western
# 5894  Hanamichi Sakuragi is a delinquent and the lea...       East Asian
# 7319  Hanamichi Sakuragi is a delinquent and the lea...       East Asian
# 5022  Hoppity the Grasshopper, after a period spent ...          Western
# 2400  Hoppity the Grasshopper, after a period spent ...          Western
# 3287  In the (fictitious) Lancashire mill town of Hi...          Western
# 3308  In the (fictitious) Lancashire mill town of Hi...          Western
# 7506  Jaihind is the journey of five people, linked ...      South Asian
# 5080  Jaihind is the journey of five people, linked ...      South Asian
# 6864  Jaihind is the journey of five people, linked ...      South Asian
# 5556  Manohar moves into a new apartment, 13B, on th...      South Asian
# 6644  Manohar moves into a new apartment, 13B, on th...      South Asian
# 2316  Nayaki is a horror movie . Nayaki is about Gay...      South Asian
# 2307  Nayaki is a horror movie . Nayaki is about Gay...      South Asian
# 7220  Ravi (Vijay), a youth from Thoothukudi, aspire...      South Asian
# 2465  Ravi (Vijay), a youth from Thoothukudi, aspire...      South Asian
# 7848  Sachin Joshi is a Kabaddi Player who loved a g...      South Asian
# 1368  Sachin Joshi is a Kabaddi Player who loved a g...      South Asian
# 5504  Sivaji, an Indian software architect, returns ...      South Asian
# 4960  Sivaji, an Indian software architect, returns ...      South Asian
# 6203  Tanisha is a young daughter of a man working f...      South Asian
# 7606  Tanisha is a young daughter of a man working f...      South Asian
# 4340  The Philippines, 1972. Mysterious things are h...  Southeast Asian
# 3494  The Philippines, 1972. Mysterious things are h...  Southeast Asian
# 4179  The background of the plot is based on the Sta...       East Asian
# 3688  The background of the plot is based on the Sta...       East Asian
# 6055  The film comes accompanied by a short mini-mov...       East Asian
# 4725  The film comes accompanied by a short mini-mov...       East Asian
# 3057  The film is set against the backdrop of unrest...      South Asian
# 5682  The film is set against the backdrop of unrest...      South Asian
# 95    The film opens with two people – a man (Aravin...      South Asian
# 1641  The film opens with two people – a man (Aravin...      South Asian
# 7629  The film starts in the 1980s. A young Shiva (J...      South Asian
# 1546  The film starts in the 1980s. A young Shiva (J...      South Asian
# 5400  The lives of three people take a turn when one...  Southeast Asian
# 8008  The lives of three people take a turn when one...  Southeast Asian
# 4628  While vacationing, Koenma is kidnapped by a pa...       East Asian
# 3336  While vacationing, Koenma is kidnapped by a pa...       East Asian

# %% [markdown]
# # Feature Selection

# %%
# %autoreload 2
from src.logratioanalysis import LogRatioAnalysis

logratio_title = LogRatioAnalysis(df, "title", "genre")
logratio_description = LogRatioAnalysis(df, "description", "genre")

# %%
# %autoreload 2
from src.logratioanalysis import plot_scree_subplots_for_genres

genres = df.genre.unique()
plot_scree_subplots_for_genres(logratio_title)

# %%
# %autoreload 2
plot_scree_subplots_for_genres(logratio_description)

# %%
# %autoreload 2

description_tokens = logratio_description.feature_selection(25000)
title_tokens = logratio_title.feature_selection(1000)

# %%
import nltk


def select_tokens(text, selected_tokens, tokenizer=nltk.word_tokenize):
    """
    Cleans a single document by keeping only the tokens present in the selected_tokens set.

    Parameters:
    text (str): The text document to clean.
    selected_tokens (set or list): The set or list of tokens to retain in the text.
    tokenizer (function): A function to tokenize the text (defaults to nltk.word_tokenize).

    Returns:
    str: The cleaned text with only the selected tokens.
    """

    if isinstance(text, str):
        tokens = tokenizer(text)
        filtered_tokens = [token for token in tokens if token in selected_tokens]
        return " ".join(filtered_tokens)
    return text

# %%
# Didn't Work :')
# df['cleaned_description'] = df["description"].apply(select_tokens, selected_tokens=description_tokens)

# %% [markdown]
# # Modelling

# %%
# %autoreload 2
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df["genre"] = label_encoder.fit_transform(df["genre"])
df["director"] = df["director"].fillna("")

X_train = df.drop("genre", axis=1)
y_train = df["genre"]

# %%
# %autoreload 2
from mlxtend.feature_selection import ColumnSelector
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import make_pipeline, make_union
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.ensemble import HistGradientBoostingClassifier
from skrub import SelectCols, SimilarityEncoder

text_pipeline = make_union(
    make_pipeline(
        ColumnSelector("title", drop_axis=True),
        TfidfVectorizer(ngram_range=(2, 4)),
        StandardScaler(with_mean=False),
        TruncatedSVD(),
    ),
    make_pipeline(
        ColumnSelector("description", drop_axis=True),
        TfidfVectorizer(),
        StandardScaler(with_mean=False),
        TruncatedSVD(),
    ),
    make_pipeline(SelectCols("region"), SimilarityEncoder()),
    make_pipeline(SelectCols("from"), OneHotEncoder(sparse_output=False)),
    make_pipeline(
        ColumnSelector("director", drop_axis=True),
        TfidfVectorizer(ngram_range=(1, 2)),  #
        StandardScaler(with_mean=False),
        TruncatedSVD(),
    ),
)

pipeline = make_pipeline(text_pipeline, HistGradientBoostingClassifier())
pipeline

# %%
from scipy.stats import loguniform, randint
from sklearn.model_selection import RandomizedSearchCV


# Update param_distributions to match HistGradientBoostingClassifier
param_distributions = {
    "histgradientboostingclassifier__learning_rate": loguniform(0.03, 0.07),
    "histgradientboostingclassifier__max_iter": randint(250, 350),
    "histgradientboostingclassifier__max_depth": randint(4, 6),
    "histgradientboostingclassifier__min_samples_leaf": randint(85, 95),
    "histgradientboostingclassifier__max_leaf_nodes": randint(120, 140),
    "histgradientboostingclassifier__l2_regularization": loguniform(0.0005, 0.003),
    "featureunion__pipeline-1__truncatedsvd__n_components": randint(200, 400),
    "featureunion__pipeline-2__truncatedsvd__n_components": randint(800, 2000),
    "featureunion__pipeline-5__truncatedsvd__n_components": randint(200, 400),
}

# Set up the RandomizedSearchCV with the updated parameters
random_search = RandomizedSearchCV(
    pipeline,
    param_distributions=param_distributions,
    n_iter=10,
    cv=3,
    scoring="accuracy",
    random_state=42,
    verbose=4,
    error_score="raise",
)

# Fit the RandomizedSearchCV with the updated pipeline
random_search.fit(X_train, y_train)

# Get the best parameters, score, and model
best_params = random_search.best_params_
best_score = random_search.best_score_
best_model = random_search.best_estimator_

print("\n Best Parameters:", best_params)
print("\n Best Score:", best_score)
